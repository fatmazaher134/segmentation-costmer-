# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('I://تطبيق machine//segmentation data.csv')

# %%
data.drop('ID',inplace=True,axis=1)

from sklearn.preprocessing import MinMaxScaler
sc=MinMaxScaler()
sc.fit(data)
data=sc.transform(data)
data=pd.DataFrame(data)
data
# Out:
#         0    1         2         3         4    5    6
# 0     0.0  0.0  0.844828  0.666667  0.324781  0.5  1.0
# 1     1.0  1.0  0.068966  0.333333  0.420210  0.5  1.0
# 2     0.0  0.0  0.534483  0.333333  0.195144  0.0  0.0
# 3     0.0  0.0  0.465517  0.333333  0.496223  0.5  0.5
# 4     0.0  0.0  0.603448  0.333333  0.413842  0.5  0.5
# ...   ...  ...       ...       ...       ...  ...  ...
# 1995  1.0  0.0  0.500000  0.333333  0.320595  0.0  0.0
# 1996  1.0  1.0  0.155172  0.333333  0.299460  0.5  0.0
# 1997  0.0  0.0  0.224138  0.000000  0.184871  0.0  0.0
# 1998  1.0  1.0  0.103448  0.333333  0.227162  0.0  0.0
# 1999  0.0  0.0  0.120690  0.000000  0.119123  0.0  0.0
#
# [2000 rows x 7 columns]

# %%
from sklearn.cluster import KMeans

error=[]
for i in range (1,11):
    kmean= KMeans(n_clusters=i)
    kmean.fit(data)
    error.append(kmean.inertia_)
    
# plot the result
plt.figure(figsize=(10,5))
plt.plot(range(1,11),error, color='red',marker='8')
plt.xticks(np.arange(1,11,1))
# Out:
# ([<matplotlib.axis.XTick at 0x22641918e80>,
#   <matplotlib.axis.XTick at 0x22641918e50>,
#   <matplotlib.axis.XTick at 0x226418fd9d0>,
#   <matplotlib.axis.XTick at 0x22641f54a90>,
#   <matplotlib.axis.XTick at 0x22641f54fa0>,
#   <matplotlib.axis.XTick at 0x22641f6d4f0>,
#   <matplotlib.axis.XTick at 0x22641f6da00>,
#   <matplotlib.axis.XTick at 0x22641f6df10>,
#   <matplotlib.axis.XTick at 0x22641f73460>,
#   <matplotlib.axis.XTick at 0x22641f73970>],
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
km=KMeans(n_clusters=5)
km.fit(data)
y=km.predict(data)
y=pd.DataFrame(y)
print(y)
data['class']=y
# Out:
#       0
# 0     0
# 1     1
# 2     2
# 3     0
# 4     0
# ...  ..
# 1995  4
# 1996  1
# 1997  2
# 1998  1
# 1999  2
#
# [2000 rows x 1 columns]

# %%
data
# Out:
#         0    1         2         3         4    5    6  class
# 0     0.0  0.0  0.844828  0.666667  0.324781  0.5  1.0      0
# 1     1.0  1.0  0.068966  0.333333  0.420210  0.5  1.0      1
# 2     0.0  0.0  0.534483  0.333333  0.195144  0.0  0.0      2
# 3     0.0  0.0  0.465517  0.333333  0.496223  0.5  0.5      0
# 4     0.0  0.0  0.603448  0.333333  0.413842  0.5  0.5      0
# ...   ...  ...       ...       ...       ...  ...  ...    ...
# 1995  1.0  0.0  0.500000  0.333333  0.320595  0.0  0.0      4
# 1996  1.0  1.0  0.155172  0.333333  0.299460  0.5  0.0      1
# 1997  0.0  0.0  0.224138  0.000000  0.184871  0.0  0.0      2
# 1998  1.0  1.0  0.103448  0.333333  0.227162  0.0  0.0      1
# 1999  0.0  0.0  0.120690  0.000000  0.119123  0.0  0.0      2
#
# [2000 rows x 8 columns]
